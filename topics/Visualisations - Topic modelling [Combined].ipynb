# %%
import pandas as pd
import numpy as np
import pycountry_convert as pc
from countrygroups import G20
import plotly.express as px

# %%
combined_topics_final = pd.read_csv("/Users/jiaminlim/Documents/Research/climate_nlp/IPCCandPolicy/topics/output - ipcc/ipcc_topics_final_fixed_20240521.csv")
combined_topics_final_reps = pd.read_csv("/Users/jiaminlim/Documents/Research/climate_nlp/IPCCandPolicy/topics/output - ipcc/ipcc_topics_final_reps_fixed_20240521.csv")
combined_topics_dist = pd.read_csv("/Users/jiaminlim/Documents/Research/climate_nlp/IPCCandPolicy/topics/output - ipcc/ipcc_topic_dist_20240521.csv")

#combined_topics_final = pd.read_csv("/Users/jiaminlim/Documents/Research/climate_nlp/IPCCandPolicy/topics/output - combined/29topics/combined_topics_final_fixed_20240521_29topics.csv")
#combined_topics_final_reps = pd.read_csv("/Users/jiaminlim/Documents/Research/climate_nlp/IPCCandPolicy/topics/output - combined/29topics/combined_topics_final_reps_fixed_20240521_29topics.csv")
#combined_topics_dist = pd.read_csv("/Users/jiaminlim/Documents/Research/climate_nlp/IPCCandPolicy/topics/output - combined/29topics/combined_topic_dist_20240521_29topics.csv")

#combined_topics_final = pd.read_csv("/Users/jiaminlim/Documents/Research/climate_nlp/IPCCandPolicy/topics/output - combined/auto/combined_topics_final_fixed_20240521_auto.csv")
#combined_topics_final_reps = pd.read_csv("/Users/jiaminlim/Documents/Research/climate_nlp/IPCCandPolicy/topics/output - combined/auto/combined_topics_final_reps_fixed_20240521_auto.csv")
#combined_topics_dist = pd.read_csv("/Users/jiaminlim/Documents/Research/climate_nlp/IPCCandPolicy/topics/output - combined/auto/combined_topic_dist_20240521_auto.csv")

# %% [markdown]
# ### Creating topic name dataframe

# %%
combined_topics_final_reps = combined_topics_final_reps.transpose()
combined_topics_final_reps = combined_topics_final_reps.iloc[2: , :]
combined_topics_final_reps = combined_topics_final_reps.reset_index()
combined_topics_final_reps = combined_topics_final_reps.rename(columns={'index': 'Topic'}) 
# combined_topics_final_reps

# %%
by_topic_count = combined_topics_final.groupby(['Topic','Name']).agg(topic_count = ('text','count'))
by_topic_count['%_total'] = round(by_topic_count['topic_count'] / by_topic_count['topic_count'].sum()*100,0)
by_topic_count = by_topic_count.reset_index()
# by_topic_count

# %%
combined_topics_final_reps['Topic'] = combined_topics_final_reps['Topic'].astype(int) 
by_topic_count['Topic'] = by_topic_count['Topic'].astype(int) 

df_topics = combined_topics_final_reps.merge(by_topic_count, on = 'Topic',how='inner')

df_topics = df_topics.rename(columns={'0': 'Document1','1': 'Document2','2': 'Document3','Name': 'Top_words'})
#df_topics
df_topics.to_csv('ipcc_topics_final_reps_fixed2.csv')

# %%
df_topics['Top_words'] = df_topics['Top_words'].str.replace('_',', ').str.split(',', n=1).str.get(-1)

# %%
df_topics
# Out:
#     Topic                                                  0  \
# 0       0  As mentioned in Section 3.3.1, there is an imp...
# 1       1  If obstacles to accelerated mitigation are roo...
# 2       2  compatible with lower emissions have demonstra...
# 3       3  In this report, desertification is defined as ...
# 4       4  Bioenergy with carbon dioxide capture and stor...
# 5       5  In this section, the impacts on desertificatio...
# 6       6  Aerosol A suspension of airborne solid or liqu...
# 7       7  Figure SPM.S| Sea level rise risks and respons...
# 8       8  Emission scenario A plausible representation o...
# 9       9  Department of Geographical Sciences, Universit...
# 10     10  In this Special Report, the degree of agreemen...
# 11     11  Integrated water management provides large co-...
# 12     12  Carbon price The price for avoided or released...
# 13     13  Multiple datasets and models show that the rat...
# 14     14  Land degradation processes with direct impact ...
# 15     15  Disaster risk management (DRM) Processes for d...
# 16     16  Figure TS.31 | Geophysical, environmental-ecol...
# 17     17  Anthropogenic climate change has increased obs...
# 18     18  A functional unit consisting of living organis...
# 19     19  This special report assesses new knowledge sin...
#
#                                                     1  \
# 0   The rate of sea level rise since the mid-19th ...
# 1   International climate agreements, rising natio...
# 2   Food loss and waste impacts food security by r...
# 3   Table 4.2 | Interaction of human and climate d...
# 4   IAMs assume bioenergy to be supplied mostly fr...
# 5   In this section, the impacts on climate change...
# 6   5 y y at Effective radiative forcing (ERF) See...
# 7   SLR, as well as the context for adaptation, wi...
# 8   Emission scenario A plausible representation o...
# 9   Institute for Governance & Sustainable Develop...
# 10  The robustness of a finding based on the type,...
# 11  Attribution of success in soil and water conse...
# 12  Economic instruments have been effective in re...
# 13  The carbon cycle provides for additional feedb...
# 14  Agroforestry can curb GHG emissions of CO₂, CH...
# 15  Disaster risk management (DRM) Processes for d...
# 16  In this report, feasibility refers to the pote...
# 17  The average intensity of tropical cyclones, th...
# 18  Ecosystem An ecosystem is a functional unit co...
# 19  This special report assesses new knowledge sin...
#
#                                                     2  \
# 0   Figure SPM.3 (continued): (a) depth integrated...
# 1   Approaches that align goals and actions across...
# 2   Sustainable food supply and food consumption, ...
# 3   Desertification is land degradation in arid, s...
# 4   Bioenergy with carbon dioxide capture and stor...
# 5   Table 6.8 Integrated response options based on...
# 6   A suspension of airborne solid or liquid parti...
# 7   Flood risk studies that have included adaptati...
# 8   A plausible representation of the future devel...
# 9   U.S. Department of Health and Human Services T...
# 10  This technical summary complements and expands...
# 11  policies aimed at improving water use efficien...
# 12  C.6.4 Regulatory and economic instruments coul...
# 13  Multiple datasets and models show that the rat...
# 14  Global warming is expected to accelerate soil ...
# 15  Disaster risk management (DRM) Processes for d...
# 16  Feasibility In this report, feasibility refers...
# 17  The average intensity of tropical cyclones, th...
# 18  An ecosystem is a functional unit consisting o...
# 19  Each chapter of SROCC presents an integrated s...
#
#                                        Top_words  topic_count  %_total
# 0              confidence, warming, ice, changes         8320     50.0
# 1      energy, development, pathways, mitigation         3567     21.0
# 2               food, production, security, land         1164      7.0
# 3    desertification, degradation, land, erosion          557      3.0
# 4                    bioenergy, cdr, beccs, land          399      2.0
# 5            options, response, management, land          300      2.0
# 6             srm, aerosol, radiation, radiative          269      2.0
# 7                  coastal, slr, protection, sea          268      2.0
# 8       scenarios, scenario, socioeconomic, ssps          244      1.0
# 9              united, states, america, sciences          238      1.0
# 10        report, findings, likelihood, evidence          200      1.0
# 11       water, irrigation, drought, groundwater          171      1.0
# 12                carbon, costs, discount, price          171      1.0
# 13              carbon, ocean, atmospheric, sink          137      1.0
# 14                  soil, carbon, organic, soils          121      1.0
# 15        disaster, insurance, risk, instruments          119      1.0
# 16      feasibility, mitigation, option, options          110      1.0
# 17               tropical, cyclones, cyclone, tc          105      1.0
# 18                ecosystem, services, es, human          106      1.0
# 19             cryosphere, ocean, srocc, changes          100      1.0

# %%
df_topics[['Topic','Top_words','topic_count','%_total']]
# Out:
#     Topic                                     Top_words  topic_count  %_total
# 0       0             confidence, warming, ice, changes         8320     50.0
# 1       1     energy, development, pathways, mitigation         3567     21.0
# 2       2              food, production, security, land         1164      7.0
# 3       3   desertification, degradation, land, erosion          557      3.0
# 4       4                   bioenergy, cdr, beccs, land          399      2.0
# 5       5           options, response, management, land          300      2.0
# 6       6            srm, aerosol, radiation, radiative          269      2.0
# 7       7                 coastal, slr, protection, sea          268      2.0
# 8       8      scenarios, scenario, socioeconomic, ssps          244      1.0
# 9       9             united, states, america, sciences          238      1.0
# 10     10        report, findings, likelihood, evidence          200      1.0
# 11     11       water, irrigation, drought, groundwater          171      1.0
# 12     12                carbon, costs, discount, price          171      1.0
# 13     13              carbon, ocean, atmospheric, sink          137      1.0
# 14     14                  soil, carbon, organic, soils          121      1.0
# 15     15        disaster, insurance, risk, instruments          119      1.0
# 16     16      feasibility, mitigation, option, options          110      1.0
# 17     17               tropical, cyclones, cyclone, tc          105      1.0
# 18     18                ecosystem, services, es, human          106      1.0
# 19     19             cryosphere, ocean, srocc, changes          100      1.0

# %%
equiv_gpt = {0:"Climate Change Impacts", 
        1:"Carbon Accounting in Forest Management",
        2:"Livestock Manure Management",
        3:"Waste Management and Treatment",
        4:"Uncertainty Assessment in Emissions Inventory",
        5:"Citation of IPCC Guidelines Equations",
             
        6:"Energy Fuel Consumption",
        7:"Global Warming Potential (GWP) Reporting",
        8:"Default Emission Factor Calculation (2006 IPCC Guidelines)",
        9:"National Greenhouse Gas Inventories Guidelines",
        10:"National GHG Inventory Compilation",
             
        11:"National GHG Inventory Development",
        12:"Default CH4 Emission Factors",
        13:"Greenhouse Gas Emissions by Sector (2017)",
        14:"Tiered Method for Emission Factor Calculation",
        15:"QA/QC Procedures in Inventory Compilation",
             
        16:"Greenhouse Gas Inventory Composition",
        17:"Refrigeration and Air Conditioning HFC Usage",
        18:"Key Categories Analysis",
        19:"Agriculture, Forestry, and Other Land Use (AFOLU) Sector Analysis",
        20:"Industrial Carbonate Calcination Processes",
             
        21:"Cement Clinker Production Emissions",
        22:"Quality Control for Activity Data and Emission Factors",
        23:"Estimating GHG Emissions using IPCC Tier 1 Approach",
        24:"GHG Emissions from Iron and Steel Production",
        25:"GHG Emissions Estimation: Reference vs Sectoral Approach",
             
        26:"GHG Key Category Analysis: IPCC Tier 2 Level",
        27:"Inventory Completeness Assessment and Software Utilization",
        28:"Wetlands Emission Estimation and IPCC Supplement Utilization"}
df_topics["topic_phrase_gpt"] = df_topics["Topic"].map(equiv_gpt)

# %%
equiv_manual = {0:"Climate Change Scenarios and Impacts", 
        1:"Emissions from Forest Management",
        2:"Emissions from Livestock Manure Management",
        3:"Emissions from Solid Waste Disposal",
        4:"Uncertainties in Inventory Estimates",
        5:"Citations of 2006 IPCC guidelines",
         
        6:"Emissions from Fuels & Energy",
        7:"Global Warming Potential Values",
        8:"Emission Factors from 2006 IPCC Guidelines",
        9:"National Greenhouse Gas Inventories 1",
        10:"National Greenhouse Gas Inventories 2",
         
        11:"National Greenhouse Gas Inventories 3",
        12:"Default values for CO2 and CH4 Emission Factors",
        13:"2017 Greenhouse Gas Emissions",
        14:"Tier methods for Estimating Inventory",
        15:"QA/QC Procedures in Inventory Compilation",
         
        16:"Greenhouse Gas Inventory Composition",
        17:"Emissions from Refridgeration and Hydroflourocarbons (HFCs)",
        18:"Key Categories Analysis",
        19:"Emissions from Agriculture, Forestry, and Other Land Use (AFOLU)",
        20:"Emissions from Industrial Carbonate Calcination Processes",
         
        21:"Emissions from Cement Clinker Production",
        22:"Activity Data and Emission Factors",
        23:"Tier approaches for Estimating Inventory",
        24:"Emissions from Iron and Steel Production",
        25:"GHG Emissions Estimation: Reference vs Sectoral Approach",
         
        26:"Key Category Level Analysis",
        27:"Inventory Completeness Assessment",
        28:"Emissions from Wetlands Supplement"}
df_topics["topic_phrase_manual"] = df_topics["Topic"].map(equiv_manual)

# %%
equiv_manual_final = {0:"Climate Change Scenarios and Impacts", 
        1:"Emissions from Forest Management",
        2:"Emissions from Livestock Manure Management",
        3:"Emissions from Solid Waste Disposal",
        4:"Uncertainties in Inventory Estimates",
        5:"Citations of 2006 IPCC guidelines",
         
        6:"Emissions from Fuels & Energy",
        7:"Global Warming Potential Values",
        8:"Emission Factors from 2006 IPCC Guidelines",
        9:"National Greenhouse Gas Inventories",
        10:"National Greenhouse Gas Inventories",
         
        11:"National Greenhouse Gas Inventories",
        12:"Default values for CO2 and CH4 Emission Factors",
        13:"2017 Greenhouse Gas Emissions",
        14:"Tier methods/approaches for Estimating Inventory",
        15:"QA/QC Procedures in Inventory Compilation",
         
        16:"Greenhouse Gas Inventory Composition",
        17:"Emissions from Refridgeration and Hydroflourocarbons (HFCs)",
        18:"Key Categories Analysis",
        19:"Emissions from Agriculture, Forestry, and Other Land Use (AFOLU)",
        20:"Emissions from Industrial Carbonate Calcination Processes",
         
        21:"Emissions from Cement Clinker Production",
        22:"Activity Data and Emission Factors",
        23:"Tier methods/approaches for Estimating Inventory",
        24:"Emissions from Iron and Steel Production",
        25:"GHG Emissions Estimation: Reference vs Sectoral Approach",
         
        26:"Key Categories Analysis",
        27:"Inventory Completeness Assessment",
        28:"Emissions from Wetlands Supplement"}
df_topics["topic_phrase_manual_final"] = df_topics["Topic"].map(equiv_manual_final)

# %%
equiv_manual_final_groups = {0:"Climate Change Scenarios and Impacts", 
        1:"GHG Emissions - Agriculture & LULUCF",
        2:"GHG Emissions - Agriculture & LULUCF",
        3:"GHG Emissions - Waste",
        4:"GHG Emisions Measurement & Methods (General)",
        5:"GHG Emisions Measurement & Methods (General)",
         
        6:"GHG Emissions - Energy",
        7:"GHG Emisions Measurement & Methods (General)",
        8:"GHG Emisions Measurement & Methods (General)",
        9:"GHG Emisions Measurement & Methods (General)",
        10:"GHG Emisions Measurement & Methods (General)",
         
        11:"GHG Emisions Measurement & Methods (General)",
        12:"GHG Emisions Measurement & Methods (General)",
        13:"GHG Emisions Measurement & Methods (General)",
        14:"GHG Emisions Measurement & Methods (General)",
        15:"GHG Emisions Measurement & Methods (General)",
         
        16:"GHG Emisions Measurement & Methods (General)",
        17:"GHG Emissions - IPPU",
        18:"GHG Emisions Measurement & Methods (General)",
        19:"GHG Emissions - Agriculture & LULUCF",
        20:"GHG Emissions - IPPU",
         
        21:"GHG Emissions - IPPU",
        22:"GHG Emisions Measurement & Methods (General)",
        23:"GHG Emisions Measurement & Methods (General)",
        24:"GHG Emissions - IPPU",
        25:"GHG Emisions Measurement & Methods (General)",
         
        26:"GHG Emisions Measurement & Methods (General)",
        27:"GHG Emisions Measurement & Methods (General)",
        28:"GHG Emissions - Agriculture & LULUCF"}
df_topics["topic_phrase_manual_final_group"] = df_topics["Topic"].map(equiv_manual_final_groups)

# %%
combined_topics_dist
combined_topics_dist = combined_topics_dist.rename(columns={'Unnamed: 0': 'Topic','count_x': 'n_before','count_y': 'n_after'})
combined_topics_dist

df_topics = df_topics.merge(combined_topics_dist, on = 'Topic',how='right')

# %%
df_topics['n_diff'] = df_topics['n_after'] - df_topics['n_before']
# table = df_topics[['topic_phrase_manual_final','topic_phrase_manual','topic_phrase_gpt','topic_phrase_manual_final_group','Top_words',0,1,2]]
table = df_topics[['topic_phrase_gpt','topic_phrase_manual','topic_phrase_manual_final','topic_phrase_manual_final_group','Top_words',0]]
# table = df_topics[['topic_phrase_manual_final','n_before','n_after','n_diff']]

table.to_latex()

# %%
table

# %% [markdown]
# ### Map topic names to main dataframe

# %%
# Map topic phrases back to main frame
combined_topics_final = combined_topics_final.merge(df_topics[['Topic','topic_phrase_manual_final','topic_phrase_manual_final_group']], on = 'Topic',how='left')
combined_topics_final = combined_topics_final.rename({'topic_phrase_manual_final': 'Topic Phrase'}, axis='columns')
combined_topics_final = combined_topics_final.rename({'topic_phrase_manual_final_group': 'Topic Phrase Group'}, axis='columns')

#combined_topics_final
len(combined_topics_final)

# %%
combined_topics_final['Topic Phrase'].nunique()

# %% [markdown]
# ### Analysis - By Topic

# %%
by_topic = (100.0*combined_topics_final.groupby('Topic Phrase')['text'].size().sort_values(ascending= False)/len(combined_topics_final)).round(1)
print(by_topic.to_latex())

# %%
top10topics_df = by_topic[0:10,].reset_index()
top10topics = top10topics_df.iloc[:,0]
top10topics =top10topics.tolist()

# %%
combined_topics_final_top10 = combined_topics_final[combined_topics_final['Topic Phrase'].isin(top10topics)]
len(combined_topics_final_top10)/len(combined_topics_final)*100.0

# %%
combined_topics_final_top10 = combined_topics_final_top10[combined_topics_final_top10['year']>2006]

total_counts_per_year = combined_topics_final.groupby('year')['text'].size()

share_of_total = 100*combined_topics_final_top10.groupby(['year', 'Topic Phrase'])['text'].size() / total_counts_per_year

#combined_topics_final_top10.groupby(['year','topic_phrase'])['text'].size().unstack().plot(kind='line')
share_of_total.unstack().plot(figsize=(15,6),
                              kind='line',
                              #kind='bar',
                              #stacked =True,
                              xlabel='Year',
                              ylabel='Share of Rows in each Year(%)')

# %% [markdown]
# #### Top 20 topics by Continent

# %%
# Exclude null
combined_topics_final = combined_topics_final[combined_topics_final['Continent']!="null"]
combined_topics_final_top10 = combined_topics_final_top10[combined_topics_final_top10['Continent']!="null"]

total_counts_per_cont = combined_topics_final[combined_topics_final['Continent'] != "null"].groupby('Continent')['text'].size()

share_of_total = 100*combined_topics_final_top10.groupby(['Topic Phrase','Continent'])['text'].size() / total_counts_per_cont

#combined_topics_final_top10.groupby(['year','topic_phrase'])['text'].size().unstack().plot(kind='line')
share_of_total.unstack().plot(figsize=(15,6),
                              kind='bar',
                              stacked =False,
                              legend = 'reverse',
                              xlabel='Continent',
                              ylabel='Share of Total Rows from given Continent (%)')

# %% [markdown]
# ### By group topics

# %%
by_topic_groups2 = (100.0*combined_topics_final.groupby(['Topic Phrase Group','Topic Phrase'])['text'].size()/len(combined_topics_final)).round(1)
by_topic_groups2.to_latex()

# %%
df_topicsresults = pd.DataFrame(by_topic_groups2.ffill(limit=None))
df_topicsresults = df_topicsresults.reset_index()
df_topicsresults = df_topicsresults.rename(columns={'text': 'topic share'})
df_topicsresults
# Need to add a total line??

# %%
# df = px.data.gapminder().query("year == 2007")
fig = px.treemap(df_topicsresults, path=['Topic Phrase Group', 'Topic Phrase'], values='topic share',
                 color='Topic Phrase Group',
                 color_discrete_map={'Climate Change Scenarios and Impacts':'#1F77B4',
                                      'GHG Emisions Measurement & Methods (General)':'#FF7F0E',
                                     'GHG Emissions - Agriculture & LULUCF':'#2CA02C',
                                     'GHG Emissions - Energy':'#D62728',
                                     'GHG Emissions - IPPU':'#9467BD',
                                      'GHG Emissions - Waste':'#8C564B'})
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))

# Manually adjust figure labels
for i in range(0,len(fig.data[0]['labels'])):
    label = fig.data[0]['labels'][i]
    if len(label.split())-1 >= 3:
        new_label = ' '.join(label.split()[:3]) + " <br>" + ' '.join(label.split()[3:len(label.split())])
        fig.data[0]['labels'][i] = new_label
fig.data[0]['labels'][11] = 'Climate Change Scenarios and Impacts'
fig.data[0]['labels'][12] = 'Citations of 2006 IPCC guidelines'

fig.data[0]['textfont']['size'] = 20
fig.show()
#fig.write_image("topic_treemap.png")

# %%
by_topic_groups = (100.0*combined_topics_final.groupby('Topic Phrase Group')['text'].size().sort_values(ascending= False)/len(combined_topics_final)).round(1)
print(by_topic_groups.to_latex())

# %%
total_counts = combined_topics_final.groupby('year')['text'].size()
topics_per_year = combined_topics_final.groupby(['year','Topic Phrase Group'])['text'].size()
share_of_total = 100.0*topics_per_year / total_counts

fig = topics_per_year.unstack().plot(figsize=(15,6),
                              #kind='line',
                              kind='bar',
                              stacked =True,
                              xlabel='Year',
                              ylabel='Number of Rows')
#fig.invert_yaxis()
fig.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %%
total_counts = combined_topics_final.groupby('types0')['text'].size()
topics_per_type = combined_topics_final.groupby(['types0','Topic Phrase Group'])['text'].size()
share_of_total = 100.0*topics_per_type / total_counts

fig = topics_per_type.unstack().plot(figsize=(15,6),
                              #kind='line',
                              kind='barh',
                              stacked =True,
                              xlabel='Number of Rows',
                              ylabel='Document Type')
fig.invert_yaxis()
fig.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
#fig.savefig('topic_doc2.png', dpi=300)

# %%
total_counts = combined_topics_final.groupby('types0')['text'].size()
topics_per_type = len(combined_topics_final)
share_of_total = 100.0* total_counts/topics_per_type
share_of_total

# %%
g20_list = G20

# G20 countries - National Comm
subset = combined_topics_final[(combined_topics_final['geography_iso'].isin(G20)) & (combined_topics_final['types0']=='National Communication')]

total_counts = subset.groupby('geography_iso')['text'].size()
topics_per_country = subset.groupby(['geography_iso','Topic Phrase Group'])['text'].size()
share_of_total = 100.0*topics_per_country / total_counts

fig = share_of_total.unstack().plot(figsize=(15,6),
                              #kind='line',
                              kind='bar',
                              stacked =True,
                              xlabel='G20 country',
                              ylabel='Share of Rows (%)')
fig.invert_yaxis()
fig.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %%
# G20 countries - National Inventory Report
subset = combined_topics_final[(combined_topics_final['geography_iso'].isin(G20)) & (combined_topics_final['types0']=='National Inventory Report')]

total_counts = subset.groupby('geography_iso')['text'].size()
topics_per_country = subset.groupby(['geography_iso','Topic Phrase Group'])['text'].size()
share_of_total = 100.0*topics_per_country / total_counts

fig = share_of_total.unstack().plot(figsize=(15,6),
                              #kind='line',
                              kind='bar',
                              stacked =True,
                              xlabel='Share of Rows (%)',
                              ylabel='Document Type')
fig.invert_yaxis()
fig.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %% [markdown]
# #### Visualise first topic

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

#text = " ".join(txt for txt in combined_topics_final[combined_topics_final['Topic Phrase Group']=='GHG Emisions Measurement & Methods (General)']['text'])
#text = " ".join(txt for txt in combined_topics_final[combined_topics_final['Topic Phrase Group']=='GHG Emissions - Agriculture & LULUCF']['text'])
#text = " ".join(txt for txt in combined_topics_final[combined_topics_final['Topic Phrase Group']=='Climate Change Scenarios and Impacts']['text'])

#text = " ".join(txt for txt in combined_topics_final[combined_topics_final['Topic Phrase']=='Emissions from Forest Management']['text'])
text = " ".join(txt for txt in combined_topics_final[combined_topics_final['Topic Phrase']=='National Greenhouse Gas Inventories']['text'])

# Create stopword list:
stopwords = set(STOPWORDS)
# Same stopword list that is used for topic modelling
stopwords.update(['et','al','institute','university','climate','change','box','figure','table','ipcc','emission','emissions','guidelines','C'])


x, y = np.ogrid[:300, :300]

#mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)

# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(stopwords=stopwords, max_font_size=50, max_words=100, background_color="white",mask=mask).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
import re

def countOccurrences(string, w):
    string = str(string)
    # Get the regex to be checked
    regexPattern = "\\b" + w + "\\b"
     
    # Variable to count total occurrences of the given word
    count = 0
     
    for m in re.finditer(regexPattern, string, re.IGNORECASE):
        # Increment count
        count += 1
         
    # Print the occurrences of the word
    #print(count)
    return count
