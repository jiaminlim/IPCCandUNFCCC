# %%
import pandas as pd
import numpy as np

# %%
sent_sim = pd.read_csv('sent_sim20240423.csv')
len(sent_sim)
# Out:
# 5785

# %%
sent_sim['Text (IPCC report) - Combined']= sent_sim['Text (IPCC report) - Row Index'].apply(str) + "-" + sent_sim['Text (IPCC report)']
sent_sim['Text (IPCC mentions) - Combined']= sent_sim['Text (IPCC mentions) - Row Index'].apply(str) + "-" + sent_sim['Text (IPCC mentions)']

# %%
sent_sim = sent_sim[['Text (IPCC report) - Combined','Text (IPCC mentions) - Combined','Text (IPCC mentions) - Row Index','Text (IPCC mentions)','Distance','Ratio','Matching Text']]
sent_sim
# Out:
#                           Text (IPCC report) - Combined  \
# 0     4-Center for Global Environmental Research, Na...
# 1     4-Center for Global Environmental Research, Na...
# 2     12-Adaptation takes place at international, na...
# 3     17-This chapter frames the context, knowledge-...
# 4     17-This chapter frames the context, knowledge-...
# ...                                                 ...
# 5780     16646-In: Loss and Damage from Climate Change.
# 5781     16646-In: Loss and Damage from Climate Change.
# 5782     16646-In: Loss and Damage from Climate Change.
# 5783     16646-In: Loss and Damage from Climate Change.
# 5784  16651-et al, 2016: Tropical cyclones and clima...
#
#                         Text (IPCC mentions) - Combined  \
# 0     4217-Department of Geography, University Colle...
# 1     9955-London and Tsukuba, Japan: Department of ...
# 2     15390-A series of consultations were held at t...
# 3     5922-We have warmly welcomed the IPCC's specia...
# 4     8305-Taking into account the best available sc...
# ...                                                 ...
# 5780    9322-Intergovernmental Panel on Climate Change.
# 5781    9805-Intergovernmental Panel on Climate Change.
# 5782   12620-Intergovernmental Panel on Climate Change.
# 5783   15316-Intergovernmental Panel on Climate Change.
# 5784             17242-clean growth and climate change.
#
#       Text (IPCC mentions) - Row Index  \
# 0                                 4217
# 1                                 9955
# 2                                15390
# 3                                 5922
# 4                                 8305
# ...                                ...
# 5780                              9322
# 5781                              9805
# 5782                             12620
# 5783                             15316
# 5784                             17242
#
#                                    Text (IPCC mentions)  Distance     Ratio  \
# 0     Department of Geography, University College Lo...        62  0.747967
# 1     London and Tsukuba, Japan: Department of Geogr...        91  0.664234
# 2     A series of consultations were held at the nat...        42  0.609929
# 3     We have warmly welcomed the IPCC's special rep...       147  0.756374
# 4     Taking into account the best available science...       201  0.707046
# ...                                                 ...       ...       ...
# 5780         Intergovernmental Panel on Climate Change.        20  0.609756
# 5781         Intergovernmental Panel on Climate Change.        20  0.609756
# 5782         Intergovernmental Panel on Climate Change.        20  0.609756
# 5783         Intergovernmental Panel on Climate Change.        20  0.609756
# 5784                   clean growth and climate change.        26  0.609756
#
#                                           Matching Text
# 0     [' for Global Environmental Research, National...
# 1     ['for Global Environmental Research, National ...
# 2                      [' national and ', 'al levels.']
# 3     [' of 1.5', 'bove pre-industrial levels and re...
# 4     [' the impacts of ', 'global warming ', 'above...
# ...                                                 ...
# 5780                               [' Climate Change.']
# 5781                               [' Climate Change.']
# 5782                               [' Climate Change.']
# 5783                               [' Climate Change.']
# 5784                           [' and climate change.']
#
# [5785 rows x 7 columns]

# %%
pd.DataFrame(sent_sim.groupby('Text (IPCC report) - Combined')['Text (IPCC mentions) - Combined'].count().sort_values(ascending=False)).head(50)
# Out:
#                                                     Text (IPCC mentions) - Combined
# Text (IPCC report) - Combined
# 15598-It links to the IPCC Guidelines on Nation...                              231
# 11122-Report of the Intergovernmental Panel on ...                              124
# 11114-of the Intergovernmental Panel on Climate...                              123
# 8871-In the context of the IPCC Guidelines for ...                               99
# 8921-Intergovernmental Panel on Climate Change ...                               99
# 13517-Tier In the context of the IPCC Guideline...                               83
# 13388-[Note: More details can be found in 2006 ...                               78
# 13387-[Note: For a discussion of the term 'fore...                               55
# 9492-The list of models used is provided in Tab...                               45
# 11547-d y [Note: For a discussion of the term '...                               40
# 11567-[Note: More details can be found in IPCC ...                               37
# 5223-Findings are summarized in Table 3.6.                                       34
# 5954-The most important trace gases contributin...                               32
# 772-Emission sources follows the definitions by...                               26
# 14449-Cross-cutting issues and uncertainties ar...                               25
# 14645-Examples are shown in Table 4.9.                                           24
# 1234-Further details are provided in Section 16...                               22
# 13079-The ocean warming trend documented in the...                               22
# 13622-Emissions are converted into CO-equivalen...                               21
# 8713-These privileges include certain benefits ...                               21
# 5236-A summary of regional tipping points is pr...                               21
# 11998-These privileges include certain benefits...                               21
# 13607-Emissions from international aviation and...                               20
# 9866-Emissions from international aviation and ...                               20
# 5981-United Nations Framework Convention on Cli...                               20
# 3247-Emissions from international aviation and ...                               20
# 10054-assessed in the following section.                                         20
# 15083-The uncertainty of these global estimates...                               19
# 3315-Those uncertainties are not displayed in t...                               19
# 15141-The uncertainty of these global estimates...                               19
# 15193-The uncertainty of these global estimates...                               19
# 9493-Evidence from regional studies is provided...                               19
# 10349-See also Carbon dioxide (CO), Methane (CH...                               19
# 11852-All underlying data are provided in SM4.8.                                 19
# 1251-The Working Group I (WGI) contribution to ...                               18
# 2692-Estimates by Gardner et al (2013) were use...                               18
# 2608-(2015) are summarised in Table 3.2.                                         18
# 12118-A comprehensive list of land degradation ...                               18
# 13580-CO₂ emissions from net land use, land-use...                               17
# 9204-Sectoral CO₂ emissions from energy and ind...                               16
# 10388-In national greenhouse gas inventories, l...                               16
# 10391-See also United Nations Framework Convent...                               15
# 4758-Details about the approaches used are pres...                               15
# 10406-See also United Nations Framework Convent...                               15
# 3517-In: Climate Change 2014: Impacts, Adaptati...                               15
# 3655-The IPCC WG III ARS chapter on Agriculture...                               14
# 9018-The Ramsey Equation is given as follows:                                    14
# 9502-Estimates by Garcher et al (2013) were use...                               14
# 13316-al Framework Convention on Climate Change...                               12
# 16646-In: Loss and Damage from Climate Change.                                   12

# %%
# Post-processing
t1 = ~sent_sim['Text (IPCC report) - Combined'].str.contains("-of the Intergovernmental Panel on Climate Change.")
t2 = ~sent_sim['Text (IPCC report) - Combined'].str.contains("-Report of the Intergovernmental Panel on Climate Change.")
t3 = ~sent_sim['Text (IPCC report) - Combined'].str.contains("Cambridge University Press, Cambridge")
t4 = ~sent_sim['Text (IPCC report) - Combined'].str.contains("Table")
t5 = ~sent_sim['Text (IPCC report) - Combined'].str.contains(", pp.")
sent_sim = sent_sim[t1 & t2 & t3 & t4 & t5]
len(sent_sim)
# Out:
# 4939

# %%
top_matches_v1 = pd.DataFrame(sent_sim.groupby('Text (IPCC report) - Combined')['Text (IPCC mentions) - Combined'].count().sort_values(ascending=False)).head(50)
top_matches_v1
# Out:
#                                                     Text (IPCC mentions) - Combined
# Text (IPCC report) - Combined
# 15598-It links to the IPCC Guidelines on Nation...                              231
# 8871-In the context of the IPCC Guidelines for ...                               99
# 13517-Tier In the context of the IPCC Guideline...                               83
# 13388-[Note: More details can be found in 2006 ...                               78
# 13387-[Note: For a discussion of the term 'fore...                               55
# 11547-d y [Note: For a discussion of the term '...                               40
# 11567-[Note: More details can be found in IPCC ...                               37
# 5954-The most important trace gases contributin...                               32
# 772-Emission sources follows the definitions by...                               26
# 13079-The ocean warming trend documented in the...                               22
# 1234-Further details are provided in Section 16...                               22
# 13622-Emissions are converted into CO-equivalen...                               21
# 8713-These privileges include certain benefits ...                               21
# 11998-These privileges include certain benefits...                               21
# 5981-United Nations Framework Convention on Cli...                               20
# 9866-Emissions from international aviation and ...                               20
# 10054-assessed in the following section.                                         20
# 3247-Emissions from international aviation and ...                               20
# 13607-Emissions from international aviation and...                               20
# 11852-All underlying data are provided in SM4.8.                                 19
# 15141-The uncertainty of these global estimates...                               19
# 15083-The uncertainty of these global estimates...                               19
# 3315-Those uncertainties are not displayed in t...                               19
# 15193-The uncertainty of these global estimates...                               19
# 10349-See also Carbon dioxide (CO), Methane (CH...                               19
# 2692-Estimates by Gardner et al (2013) were use...                               18
# 1251-The Working Group I (WGI) contribution to ...                               18
# 13580-CO₂ emissions from net land use, land-use...                               17
# 9204-Sectoral CO₂ emissions from energy and ind...                               16
# 10388-In national greenhouse gas inventories, l...                               16
# 10391-See also United Nations Framework Convent...                               15
# 4758-Details about the approaches used are pres...                               15
# 10406-See also United Nations Framework Convent...                               15
# 3517-In: Climate Change 2014: Impacts, Adaptati...                               15
# 9502-Estimates by Garcher et al (2013) were use...                               14
# 3655-The IPCC WG III ARS chapter on Agriculture...                               14
# 9018-The Ramsey Equation is given as follows:                                    14
# 13316-al Framework Convention on Climate Change...                               12
# 16646-In: Loss and Damage from Climate Change.                                   12
# 1922-This estimate includes GHG emissions from ...                               11
# 775-Significant uncertainties are associated wi...                               11
# 3585-This estimate includes GHG emissions from ...                               11
# 15822-The focus of this section is summarised i...                               11
# 5056-Through prescribed IPCC Special Report on ...                               10
# 13370-Following the 2006 IPCC Guidelines fluxes...                               10
# 3247-Other GHG emissions are not included.                                        9
# 12344-In 2018, 34 countries have submitted a RE...                                9
# 3179-This annex provides information on the num...                                9
# 10231-Note that the Framework Convention on Cli...                                9
# 13229-Note that the United Nations Framework Co...                                9

# %%
top_matches_v2 = pd.DataFrame(sent_sim[sent_sim['Ratio']>=0.8].groupby('Text (IPCC report) - Combined')['Text (IPCC mentions) - Combined'].count().sort_values(ascending=False)).head(50)
top_matches_v2.head(50)
# Out:
#                                                     Text (IPCC mentions) - Combined
# Text (IPCC report) - Combined
# 13229-Note that the United Nations Framework Co...                                8
# 8541-Note that the United Nations Framework Con...                                8
# 4449-Note that the United Nations Framework Con...                                8
# 11949-[Note that the United Nations Framework C...                                8
# 5457-Note that the United Nations Framework Con...                                8
# 11367-Note that the United Nations Framework Co...                                8
# 10231-Note that the Framework Convention on Cli...                                8
# 11944-A change in the state of the climate that...                                5
# 3517-In: Climate Change 2014: Impacts, Adaptati...                                5
# 4449-A change in the state of the climate that ...                                5
# 8617-By definition, the characteristics of what...                                4
# 10310-Definitions of rare vary, but an extreme ...                                4
# 5456-By definition, the characteristics of what...                                4
# 5456-When a pattern of extreme weather persists...                                4
# 8617-Definitions of 'rare' vary, but an extreme...                                4
# 13303-By definition, the characteristics of wha...                                4
# 10310-By definition, the characteristics of wha...                                4
# 5570-Definitions of 'rare' vary, but an extreme...                                4
# 10310-When a pattern of extreme weather persist...                                4
# 13303-When a pattern of extreme weather persist...                                4
# 5570-By definition, the characteristics of what...                                4
# 11943-When a pattern of extreme weather persist...                                4
# 11943-By definition, the characteristics of wha...                                4
# 8549-When a pattern of extreme weather persists...                                4
# 8549-By definition, the characteristics of what...                                4
# 11452-Definitions of 'rare' vary, but an extrem...                                4
# 11452-By definition, the characteristics of wha...                                4
# 11376-When a pattern of extreme weather persist...                                4
# 13303-Definitions of 'rare' vary, but an extrem...                                4
# 11376-By definition, the characteristics of wha...                                4
# 15516-In: Global Warming of 1.5°C an IPCC speci...                                4
# 4488-When a pattern of extreme weather persists...                                4
# 4488-Definitions of 'rare' vary, but an extreme...                                4
# 4488-By definition, the characteristics of what...                                4
# 13517-Tier 1 is the basic method, Tier 2 interm...                                4
# 8871-Tier 1 is the basic method, Tier 2 interme...                                4
# 16368-By definition, the characteristics of wha...                                4
# 16309-When a pattern of extreme weather persist...                                4
# 16309-Definitions of 'rare' vary, but an extrem...                                4
# 16309-By definition, the characteristics of wha...                                4
# 13303-Extreme weather event An event that is ra...                                3
# 11452-Extreme weather event An event that is ra...                                3
# 5958-The Convention's ultimate objective is the...                                3
# 10502-The Convention's ultimate objective is th...                                3
# 11702-The Convention's ultimate objective is th...                                3
# 5570-Extreme weather event An event that is rar...                                3
# 13192-'where human interventions and practices ...                                3
# 10310-Extreme weather event An extreme weather ...                                3
# 4691-The Convention's ultimate objective is the...                                3
# 13518-The Convention's ultimate objective is th...                                3

# %%
link = r'/Users/jiaminlim/Documents/Research/climate_nlp/IPCCandPolicy/datasets/df_ipccmentions_body.csv'
df_ipccmentions_body = pd.read_csv(link)

# %%
pd.set_option('max_colwidth', 1000)
# Write a function

# %%
def create_text_panels(text):
    # text="15598-It links to the IPCC Guidelines on National Greenhouse Gas Inventories in the land sector."
    df1 = sent_sim[sent_sim['Text (IPCC report) - Combined']==text]
    df1 = df1.rename(columns={'Text (IPCC mentions)': 'sentence_text'})
    df1['Ratio'] = df1['Ratio'].round(2)
    df1 = df1.sort_values(by='Ratio',ascending=False)
    
    ind_list = df1['Text (IPCC mentions) - Row Index']
    
    df2 = df_ipccmentions_body[['text','geography_iso','document_name','date','text_block_id']].iloc[ind_list]
    df2['text_block_id'] = df2['text_block_id'].str.replace("_","")
    df2 = df2.rename(columns={'text': 'paragraph_text'})

    df1.reset_index(drop=True, inplace=True)    
    df2.reset_index(drop=True, inplace=True)
    df_comb = pd.concat([df1,df2],axis=1)
    df_comb =df_comb[['sentence_text','paragraph_text','geography_iso','document_name','date','text_block_id','Ratio','Matching Text']]
    df_comb
    
    df1 = df1[['Text (IPCC report) - Combined','Text (IPCC mentions) - Combined','Distance','Ratio','Matching Text']]

    return df1, df_comb

# %%
text = "13229-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural dimate variability observed over comparable time periods'."

score_df, matchingrows_df = create_text_panels(text)
score_df
# Out:
#                                                                                                                                                                                                                                                                                                                                             Text (IPCC report) - Combined  \
# 0  13229-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural dimate variability observed over comparable time periods'.
# 1  13229-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural dimate variability observed over comparable time periods'.
# 2  13229-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural dimate variability observed over comparable time periods'.
# 3  13229-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural dimate variability observed over comparable time periods'.
# 4  13229-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural dimate variability observed over comparable time periods'.
# 5  13229-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural dimate variability observed over comparable time periods'.
# 6  13229-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural dimate variability observed over comparable time periods'.
# 7  13229-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural dimate variability observed over comparable time periods'.
# 8  13229-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural dimate variability observed over comparable time periods'.
#
#                                                                                                                                                                                                                                                                                                                                                                                Text (IPCC mentions) - Combined  \
# 0                                       7484-Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: "a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural climate variability observed over comparable time periods."
# 1                                                    2568-EXECUTIVE SUMMAR T he United Nations Framework Convention on Climate Change (UNFCCC) defines climate change as: "change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is in addition to natural climate variability observed over comparable period of time".
# 2                                      7636-This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 3                                      7637-This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 4                                      8591-This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 5                                      8592-This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 6                                                                                                                   4152-Under the UNFCCC, climate change is defined as "a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural climate variability observed over comparable time periods".
# 7                                                                    2564-he United Nations Framework Convention on Climate Change (UNFCCC) defines climate change in the following terms: A change of climate directly or indirectly attributable to human activity, which alters the composition of the global atmosphere and adds to the natural climate variability observed over comparable time periods.
# 8  5053-The revised act directly addresses the climate change related challenges and also provides a definition of the term, reflecting common IPCC terminology (p. 3): "a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural climate variability observed over comparable time periods".
#
#    Distance  Ratio  \
# 0         5   0.99
# 1        62   0.88
# 2        71   0.88
# 3        71   0.88
# 4        71   0.88
# 5        71   0.88
# 6        90   0.84
# 7       104   0.82
# 8       126   0.76
#
#                                                                                                                                                                                                                                                                                                                                                               Matching Text
# 0  ['Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: ', 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural ', 'imate variability observed over comparable time periods']
# 1                                             ['he United Nations Framework Convention on Climate Change (UNFCCC)', 'defines climate change as: ', 'change of climate ', ' is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and ', ' is in addition to natural ', 'imate variability observed over comparable ']
# 2                                               ['the United Nations Framework Convention on Climate Change (UNFCCC), ', 'climate change ', 'a change of climate ', ' is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and ', 'addition to natural ', 'imate variability observed over comparable time periods']
# 3                                               ['the United Nations Framework Convention on Climate Change (UNFCCC), ', 'climate change ', 'a change of climate ', ' is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and ', 'addition to natural ', 'imate variability observed over comparable time periods']
# 4                                               ['the United Nations Framework Convention on Climate Change (UNFCCC), ', 'climate change ', 'a change of climate ', ' is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and ', 'addition to natural ', 'imate variability observed over comparable time periods']
# 5                                               ['the United Nations Framework Convention on Climate Change (UNFCCC), ', 'climate change ', 'a change of climate ', ' is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and ', 'addition to natural ', 'imate variability observed over comparable time periods']
# 6                                                                                        [' the U', 'limate ', 'hange ', 'define', 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural ', 'imate variability observed over comparable time periods']
# 7                                                                                                            ['e United Nations Framework Convention on Climate Change (UNFCCC)', ' change of climate ', 'irectly ', ' to human activity', ' alters the composition of the global atmosphere and ', ' natural ', 'imate variability observed over comparable time periods']
# 8                                                                                                                                 ['a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural ', 'imate variability observed over comparable time periods']

# %%
matchingrows_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                             sentence_text  \
# 0                                       Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: "a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural climate variability observed over comparable time periods."
# 1                                                    EXECUTIVE SUMMAR T he United Nations Framework Convention on Climate Change (UNFCCC) defines climate change as: "change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is in addition to natural climate variability observed over comparable period of time".
# 2                                      This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 3                                      This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 4                                      This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 5                                      This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 6                                                                                                                   Under the UNFCCC, climate change is defined as "a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural climate variability observed over comparable time periods".
# 7                                                                    he United Nations Framework Convention on Climate Change (UNFCCC) defines climate change in the following terms: A change of climate directly or indirectly attributable to human activity, which alters the composition of the global atmosphere and adds to the natural climate variability observed over comparable time periods.
# 8  The revised act directly addresses the climate change related challenges and also provides a definition of the term, reflecting common IPCC terminology (p. 3): "a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural climate variability observed over comparable time periods".
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             paragraph_text  \
# 0  Climate change refers to a change in the state of the climate that can be identified (for example, by using statistical tests) by changes in the mean and/ or the variability of its properties, and which persists for an extended period, typically decades or longer. Climate change may be due to natural internal processes or external forcings such as modulations of the solar cycles, volcanic eruptions and persistent anthropogenic changes in the composition of the atmosphere or in land use. Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: "a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural climate variability observed over comparable time periods." The UNFCCC thus makes a distinction between climate change attributable to human activities altering the atmospheric composition and climate variabili...
# 1  EXECUTIVE SUMMAR T he United Nations Framework Convention on Climate Change (UNFCCC) defines climate change as: "change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is in addition to natural climate variability observed over comparable period of time". Some of the greenhouse gases (GHG) are produced naturally, but human activities, especially those that use energy, as well as global deforestation and agricultural activities, generate additional greenhouse gases in the atmosphere. The scientific consensus on climate change attested by the fifth Assessment Report of the Intergovernmental Panel on Climate Change (IPCC) isclear (i) the climate system warming is unequivocal, and human influence is established: (i) climate change has had impacts on natural and human systems, including food production; (iii) the risk of serious, generalized and irreversible impacts is increasingly high: (iv) the highes...
# 2                                                                                                                                                                                                                                         Climate change in Intergovernmental Panel on Climate Change (IPCC) usage refers to a change in the state of the climate that can be identified (e.g. using statistical tests) by changes in the mean and/or the variability of its properties, and that persists for an extended period, typically decades or longer. It refers to any change over time, whether due to natural variability or as a result of human activity. This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 3                                                                                                                                                                                                                                         Climate change in Intergovernmental Panel on Climate Change (IPCC) usage refers to a change in the state of the climate that can be identified (e.g. using statistical tests) by changes in the mean and/or the variability of its properties, and that persists for an extended period, typically decades or longer. It refers to any change over time, whether due to natural variability or as a result of human activity. This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 4                                                                                                                                                                                                                                         Climate change in Intergovernmental Panel on Climate Change (IPCC) usage refers to a change in the state of the climate that can be identified (e.g. using statistical tests) by changes in the mean and/or the variability of its properties, and that persists for an extended period, typically decades or longer. It refers to any change over time, whether due to natural variability or as a result of human activity. This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 5                                                                                                                                                                                                                                         Climate change in Intergovernmental Panel on Climate Change (IPCC) usage refers to a change in the state of the climate that can be identified (e.g. using statistical tests) by changes in the mean and/or the variability of its properties, and that persists for an extended period, typically decades or longer. It refers to any change over time, whether due to natural variability or as a result of human activity. This usage differs from that in the United Nations Framework Convention on Climate Change (UNFCCC), where climate change refers to a change of climate that is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and that is addition to natural climate variability observed over comparable time periods.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Under the UNFCCC, climate change is defined as "a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural climate variability observed over comparable time periods". Human activities change atmospheric concentrations and distribution of greenhouse gases and aerosols. These changes can produce a radiant forcing by changing the solar radiation reflection and absorption, or emission and absorption of terrestrial radiation (IPCC, 1996).
# 7  he United Nations Framework Convention on Climate Change (UNFCCC) defines climate change in the following terms: A change of climate directly or indirectly attributable to human activity, which alters the composition of the global atmosphere and adds to the natural climate variability observed over comparable time periods. Some of the greenhouse gases (GHGs) are produced naturally, but human activities, especially those that use energy, as well as deforestation and agricultural activities on a global scale release additional greenhouse gases into the environment. &#39;atmosphere. The scientific consensus on climate change attested by the fifth assessment report of the Intergovernmental Panel on Climate Change (IPCC) is striking (i) the warming of the climate system is unequivocal, and the influence of man is established; (ii) climate change has had impacts on natural and human systems, including food production: (i) the risk of severe, widespread and irreversible impacts is increas...
# 8  The Environmental Management and Conservation Act No. 12 as amended by The Environmental Management and Conservation (Amendment) Act No. 28 (2011): The initial 2002 Act, which was amended in 2011, is the most important environmental legislation in the country. It, particularly, addresses regulations in the four areas: (i) biodiversity: (ii) environmental impact assessments; (iii) administration; (iv) bio-prospecting laws and community conservation areas (CCAs). The initial act was revised in 2011 (into the Amendment Act No. 28). The revised act directly addresses the climate change related challenges and also provides a definition of the term, reflecting common IPCC terminology (p. 3): "a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural climate variability observed over comparable time periods". It, furthermore, requests that climate change adaptation and mitigatio...
#
#   geography_iso                                            document_name  \
# 0           TTO  Trinidad and Tobago. National Communication (NC). NC 3.
# 1           CIV        Côte d'Ivoire. National Communication (NC). NC 3.
# 2           NZL                   New Zealand's Adaptation communication
# 3           NZL                   New Zealand's Adaptation communication
# 4           NZL          New Zealand. National Communication (NC). NC 7.
# 5           NZL          New Zealand. National Communication (NC). NC 7.
# 6           GNB        Guinea-Bissau. National Communication (NC). NC 3.
# 7           CIV        Côte d'Ivoire. National Communication (NC). NC 3.
# 8           VUT              Vanuatu. National communication (NC). NC 3.
#
#          date text_block_id  Ratio  \
# 0  2021-12-29         p21b2   0.99
# 1  2017-12-31         p24b7   0.88
# 2  2017-12-21        p438b3   0.88
# 3  2017-12-21        p471b4   0.88
# 4  2017-12-21        p438b3   0.88
# 5  2017-12-21        p471b4   0.88
# 6  2018-03-09         p87b2   0.84
# 7  2017-12-31         p14b8   0.82
# 8  2021-03-22        p130b8   0.76
#
#                                                                                                                                                                                                                                                                                                                                                               Matching Text
# 0  ['Note that the United Nations Framework Convention on Climate Change (UNFCCC), in its Article 1, defines climate change as: ', 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural ', 'imate variability observed over comparable time periods']
# 1                                             ['he United Nations Framework Convention on Climate Change (UNFCCC)', 'defines climate change as: ', 'change of climate ', ' is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and ', ' is in addition to natural ', 'imate variability observed over comparable ']
# 2                                               ['the United Nations Framework Convention on Climate Change (UNFCCC), ', 'climate change ', 'a change of climate ', ' is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and ', 'addition to natural ', 'imate variability observed over comparable time periods']
# 3                                               ['the United Nations Framework Convention on Climate Change (UNFCCC), ', 'climate change ', 'a change of climate ', ' is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and ', 'addition to natural ', 'imate variability observed over comparable time periods']
# 4                                               ['the United Nations Framework Convention on Climate Change (UNFCCC), ', 'climate change ', 'a change of climate ', ' is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and ', 'addition to natural ', 'imate variability observed over comparable time periods']
# 5                                               ['the United Nations Framework Convention on Climate Change (UNFCCC), ', 'climate change ', 'a change of climate ', ' is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and ', 'addition to natural ', 'imate variability observed over comparable time periods']
# 6                                                                                        [' the U', 'limate ', 'hange ', 'define', 'a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural ', 'imate variability observed over comparable time periods']
# 7                                                                                                            ['e United Nations Framework Convention on Climate Change (UNFCCC)', ' change of climate ', 'irectly ', ' to human activity', ' alters the composition of the global atmosphere and ', ' natural ', 'imate variability observed over comparable time periods']
# 8                                                                                                                                 ['a change of climate which is attributed directly or indirectly to human activity that alters the composition of the global atmosphere and which is in addition to natural ', 'imate variability observed over comparable time periods']
